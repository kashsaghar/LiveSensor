# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in .\venv\Lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in .\venv\Lib\site-packages (from pymongo) (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://kash_saghar:kimtaehyung123@cluster0.q1ak0xb.mongodb.net/?appName=Cluster0" 

client = MongoClient(connection_string)

# %%
db = client["liveclass"]
collection = db["mongoclass"]

# %%
data = {"name": "John", "age": 30, "city": "New York"}

# %%
collection.insert_one(data)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6a2ea3e2a3d5b3afca73d24b'), 'name': 'John', 'age': 30, 'city': 'New York'}
